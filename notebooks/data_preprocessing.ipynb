# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# %run 'data_collection.ipynb'
# Out:
# {'status': 'ok', 'totalResults': 14359, 'articles': [{'source': {'id': None, 'name': 'Ted.com'}, 'author': 'Anathea Chino, contact@ted.com (TED)', 'title': 'The power shift US politics needs | Anathea Chino', 'description': 'As the cofounder of Advance Native Political Leadership, Anathea Chino creates space for Native American leaders to thrive in an often unwelcoming political system. Alongside comedian and filmmaker Negin Farsad, she discusses the power of diverse identities i…', 'url': 'https://www.ted.com/talks/anathea_chino_the_power_shift_us_politics_needs', 'urlToImage': 'https://pi.tedcdn.com/r/talkstar-assets.s3.amazonaws.com/production/talks/talk_145748/bfd7ebaa-a34d-477c-82fe-2338a6cf3500/AnatheaChino_2024N-embed.jpg?u%5Br%5D=2&u%5Bs%5D=0.5&u%5Ba%5D=0.8&u%5Bt%5D=0.03&quality=82c=1050%2C550&w=1050', 'publishedAt': '2025-02-11T15:59:41Z', 'content': 'TED is supported by ads and partners00:00'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Verge Press Room', 'title': 'The Verge hires Tina Nguyen as senior reporter to cover the Trump administration', 'description': 'Tina Nguyen is joining The Verge as a senior reporter, covering the Trump administration, Elon Muskâ\x80\x99s takeover of the federal government, and the tech industryâ\x80\x99s embrace of the MAGA movement. Nguyen joins The Verge from Puck, where she was a founding part…', 'url': 'https://www.theverge.com/press-room/621557/tina-nguyen-joins-verge', 'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/02/Tina_Portrait-_Horiz.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200', 'publishedAt': '2025-02-28T19:15:04Z', 'content': 'Nguyen will cover the tech industrys embrace of the MAGA movement.\r\nNguyen will cover the tech industrys embrace of the MAGA movement.\r\nTina Nguyen is joining The Verge as a senior reporter, covering… [+3522 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'SEC Official Sought Staff’s No-Politics Pledge on Musk Lawsuit', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_680da6dd-cd27-49cb-b4da-5ffe395d5165', 'urlToImage': None, 'publishedAt': '2025-02-25T14:08:07Z', 'content': "If you click 'Accept all', we and our partners, including 238 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+702 chars]"}, {'source': {'id': None, 'name': 'Seths.blog'}, 'author': 'Seth Godin', 'title': 'Confusing status with skill', 'description': 'The tenured philosophy professor at Princeton might not even be half as effective a teacher as the adjunct at the community college. The head of surgery might be relatively better at meetings and politics than they are at actually helping patients. Having a l…', 'url': 'https://seths.blog/2025/02/confusing-status-with-skill/', 'urlToImage': 'https://seths.blog/wp-content/uploads/2018/06/seth_godin_ogimages_v02_18061311.jpg', 'publishedAt': '2025-02-19T09:28:00Z', 'content': 'The tenured philosophy professor at Princeton might not even be half as effective a teacher as the adjunct at the community college.\r\nThe head of surgery might be relatively better at meetings and po… [+178 chars]'}, {'source': {'id': None, 'name': 'Unpopularfront.news'}, 'author': 'John Ganz', 'title': "Big Tech's Class War Politics", 'description': 'Why Silicon Valley Bolted Right', 'url': 'https://www.unpopularfront.news/p/big-techs-class-war-politics', 'urlToImage': 'https://substackcdn.com/image/fetch/f_auto,q_auto:best,fl_progressive:steep/https%3A%2F%2Fjohnganz.substack.com%2Ftwitter%2Fsubscribe-card.jpg%3Fv%3D556689468%26version%3D9', 'publishedAt': '2025-02-01T14:45:51Z', 'content': 'In the post-election blame game, progressives have been a favorite target of the center who want to pin the Democratic debacle on left-wing overreach. Now one of the stories pundits like Matt Yglesia… ...
# FTC Chair praises Justice Thomas as ‘the most important judge of the last 100 years’ for Black History Month - The Verge
# 16 minutes - Seths.blog
# AI Will Save Dating Apps. Or Maybe Finally Kill Them - Wired
# 'Sad day for tennis' - Sinner doping ban 'leaves sour taste' - BBC News
# ChatGPT’s Political Views Are Shifting Right, a New Analysis Finds - Gizmodo.com
# iPhone voice recognition controversy: 'Racist' converts to 'Trump' - Fox News
# Saturday Night Live Played the Wrong Greatest-Hits Reel - The Atlantic
# Why Does Integer Addition Approximate Float Multiplication? - Probablydance.com
# Trump Evicts Moon Rock From Oval Office, Returns It to NASA - Gizmodo.com
# DeepSeek AI draws ire of spy agency over data hoarding and hot bias - Digital Trends

# %%
def preprocess_text(text):
  
    text = text.replace("â", "\"").replace("â", "\"")  
    text = text.replace("â", "'").replace("â", "'") 
    
    doc = nlp(text.lower())
    filtered_tokens = [token.text for token in doc if not token.is_stop and not token.is_punct]
    
    return ' '.join(filtered_tokens)

# %%
sample_text = articles[0]['description']
processed_text = preprocess_text(sample_text)
print(processed_text)
# Out:
# newly appointed federal trade commission chair andrew ferguson praised boss conservative supreme court justice clarence thomas important judge 100 years memo agency staff honoring black history month th
